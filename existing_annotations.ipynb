# %%
# %load_ext autoreload
# %autoreload 2

import pandas as pd
from os import path

# %%
annotations_df = pd.read_csv("F:\\Joel\\site06\\pilot_analyses__quick_selections__site6_depl1.txt", sep='\t', lineterminator='\r')
annotations_df
# Out:
#     Selection           View  Channel  Begin Time (s)  End Time (s)  \
# 0         \n1     Waveform 1      1.0       38.866988     41.551717
# 1         \n1  Spectrogram 1      1.0       38.866988     41.551717
# 2         \n2     Waveform 1      1.0      266.551715    269.408857
# 3         \n2  Spectrogram 1      1.0      266.551715    269.408857
# 4         \n3     Waveform 1      1.0      318.916250    321.724130
# ..        ...            ...      ...             ...           ...
# 318     \n163     Waveform 1      1.0    19477.389160  19477.943347
# 319     \n163  Spectrogram 1      1.0    19477.389160  19477.943347
# 320     \n164     Waveform 1      1.0    19484.458123  19488.583737
# 321     \n164  Spectrogram 1      1.0    19484.458123  19488.583737
# 322        \n            NaN      NaN             NaN           NaN
#
#      Low Freq (Hz)  High Freq (Hz)             Begin File  File Offset (s)  \
# ...

# %%
base = "F:\\Joel\\site06\\deployment_001\\Data"
from plotting import view_spectrogram

for i, row in annotations_df[:10].iterrows():
    view_spectrogram(
        file_path=path.join(base, row["Begin File"]),
        time_segment=(row["Begin Time (s)"], row["End Time (s)"]),
        frequency_range=(row["Low Freq (Hz)"], row["High Freq (Hz)"])
    )
# Out:
# opening  F:\Joel\site06\deployment_001\Data\6_20230316_000000.wav
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.0.0 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "c:\working\acoustic_AL\.venv\Lib\site-packages\ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
#   File "c:\working\acoustic_AL\.venv\Lib\site-packages\traitlets\config\application.py", line 1075, in launch_instance
#     app.start()
# ...
