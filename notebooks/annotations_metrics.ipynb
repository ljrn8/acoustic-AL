# %%
# %load_ext autoreload
# %autoreload 2

import pandas as pd
import numpy as np
from config import *
from util import *

# %%
ANN_DF
# Out:
#        peak_time  xcorrcoef       min_t       max_t       min_f         max_f  \
# 0     364.624000   0.584717  364.160667  365.087333  5531.00000  10125.000000
# 1     215.178667   0.658409  214.715333  215.642000  5531.00000  10125.000000
# 2     526.810667   0.604653  526.347333  527.274000  5531.00000  10125.000000
# 3     544.922667   0.663969  544.459333  545.386000  5531.00000  10125.000000
# 4     449.312000   0.610269  448.848667  449.775333  5531.00000  10125.000000
# ...          ...        ...         ...         ...         ...           ...
# 2185  384.869333   0.654130  384.514667  385.224000   205.69162    617.953796
# 2186  386.693333   0.650236  386.338667  387.048000   205.69162    617.953796
# 2187  445.056000   0.651619  444.701333  445.410667   205.69162    617.953796
# 2188  446.906667   0.683734  446.552000  447.261333   205.69162    617.953796
# 2189  448.730667   0.665214  448.376000  449.085333   205.69162    617.953796
#
# ...

# %%
metric_df = pd.DataFrame()

ds = WavDataset()
metric_df['recording'] = ds.get_wav_files()
metric_df.set_index('recording', inplace=True)
# Out:
# Empty DataFrame
# Columns: []
# ...

# %%
from util import *

mds = MauritiusDataset()
correlated_recordings_7deployments = []

for d in range(1, 8):
    print(d)
    correlated_recordings_7deployments += mds.get_recordings(d, 1)
    
correlated_recordings_7deployments

import pickle 

with open('objects/correlated_recordings_7deployments.pkl', 'wb') as f:
    pickle.dump(correlated_recordings_7deployments, f)
# Out:
# 1
# 2
# 3
# 4
# 5
# 6
# 7
